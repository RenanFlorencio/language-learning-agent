# %%
import requests

url = "https://youtube138.p.rapidapi.com/search/"

headers = {
	"x-rapidapi-key": "8685c17582mshb74f0d5f6e7ff1bp13d00ajsn1f8233ae3585",
	"x-rapidapi-host": "youtube138.p.rapidapi.com",
    "q": "aula",
    "hl": "pt",
    "gl": "PT"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'contents': [{'channel': {'avatar': [{'height': 88, 'url': 'https://yt3.googleusercontent.com/ytc/AIdro_lyLMusJCpXn2hn53V_BtgTb35yA4kjcIAYE6kiT6I1NA=s88-c-k-c0x00ffffff-no-rj-mo', 'width': 88}, {'height': 176, 'url': 'https://yt3.googleusercontent.com/ytc/AIdro_lyLMusJCpXn2hn53V_BtgTb35yA4kjcIAYE6kiT6I1NA=s176-c-k-c0x00ffffff-no-rj-mo', 'width': 176}], 'badges': [], 'canonicalBaseUrl': '/@AulaDeOnline', 'channelId': 'UChy2vDADNGfZ9r1G8l1FTYA', 'descriptionSnippet': 'O AulaDe.com.br é um projeto educacional, de cunho social, desenvolvido por um grupo de professores com o objetivo de\xa0...', 'stats': {'subscribersText': '1,56\xa0mi de inscritos'}, 'title': 'Aula De', 'username': '@AulaDeOnline'}, 'type': 'channel'}, {'type': 'video', 'video': {'author': {'avatar': [{'height': 68, 'url': 'https://yt3.ggpht.com/9LgAVVFj5ufiCen3J2N6YwNF6srDGqOXY7bCCcGitVIcYxIUk7OBf3mftK3-CgTAbQpWrkcINg=s68-c-k-c0x00ffffff-no-rj', 'width': 68}], 'badges': [], 'canonicalBaseUrl': '/@MatheusWernerJerke', 'channelId': 'UCX-fPLuEcgUWs-oSu5ttFoQ', 'title': 'Matheus Werner Jerke'}, 'badges': [], 'descriptionSnippet': 'Faça sua pré-matrícula no Cronograma dos Fluentes: https://links.matheusjerke.com.br/le25_c_yt_desc Se você quer sair do\xa0...', 'isLiveNow': False, 'lengthSeconds': 8967, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/JxHiuCI2Xro/mqdefault_6s.webp?du=3000&sqp=CIys-cwG&rs=AOn4CLBPDM-1CDkNQhaHBkBjohjU1_wQBA', 'width': 320}], 'publishedTimeText': 'Transmitido há 2 anos', 'stats': {'views': 3244168}, 'thumbnails': [{'height': 202, 'url': 'https://i.ytimg.com/vi/JxHiuCI2Xro/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAL8ZL2l54TMUUGsfFbgcfmEcGnbA', 'width': 360}, {'height': 404, 'url': 'https://i.ytimg.com/vi/JxHiuCI2Xro/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBmqwGDo213oYp5OVbdQEkFX2ZfNw', 'width': 720}], 'title': 'Aprenda Inglês em 2 Horas: Todo o Básico Que Você Precisa', 'videoId': 'JxHiuCI2Xro'}}, {'type': 'video', 'video': {'author': {'avatar': [{'height': 68, 'url': 'https://yt3.ggpht.com/vt0ITBdar63Z3XU9rljDCUWK-cPCBRutKGD_ctqMuMAAxZo6S-VO1Yy-uE-QnQutd9_NyGxyUlg=s68-c-k-c0x00ffffff-no-rj', 'width': 68}], 'badges': [{'text': 'Verificado', 'type': 'VERIFIED_CHANNEL'}], 'canonicalBaseUrl': '/@HashtagTreinamentos', 'channelId': 'UCw0leRmeaX7R_9BDd3TvCzg', 'title': 'Hashtag Treinamentos'}, 'badges': ['Novo'], 'descriptionSnippet': 'Se inscreva no Intensivão de Power BI da Hashtag:\xa0...', 'isLiveNow': False, 'lengthSeconds': 7136, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/C-_Yo_3CPxQ/mqdefault_6s.webp?du=3000&sqp=CLCb-cwG&rs=AOn4CLAqPYrN1roTuA5P90wW-A5AShl5kg', 'width': 320}], 'publishedTimeText': 'Transmitido há 1 hora', 'stats': {'views': 27941}, 'thumbnails': [{'height': 202, 'url': 'https://i.ytimg.com/vi/C-_Yo_3CPxQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAnoaG8_T7YsKb8SbHocSjBM1Yikw', 'width': 360}, {'height': 404, 'url': 'https://i.ytimg.com/vi/C-_Yo_3CPxQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLADan2zFQWAHjKGmguWBXUSJ9qUUg', 'width': 720}], 'title': 'Intensivão de Power BI [Aula 2]', 'videoId': 'C-_Yo_3CPxQ'}}, {'type': 'video', 'video': {'author': {'avatar': [{'height': 68, 'url': 'https://yt3.ggpht.com/AIvvnFN6N468DGg4QKmCHQnNj4FQ5r7qbVDpyCKJib03VeoT6q65_4SJYCGfVDRwT5bc2RTUtg=s68-c-k-c0x00ffffff-no-rj', 'width': 68}], 'badges': [], 'canonicalBaseUrl': '/@aprendainglescomlinguas', 'channelId': 'UCU2NWQKsINRzBsADP84idyQ', 'title': 'Aprenda Inglês com Línguas'}, 'badges': ['Intermediário', 'Palestra'], 'descriptionSnippet': 'Inscreva-se no canal para aprender Inglês https://www.youtube.com/@aprendainglescomlinguas?sub_confirmation=1 Nessa\xa0...', 'isLiveNow': False, 'lengthSeconds': 3743, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/fLwT0I-ksC0/mqdefault_6s.webp?du=3000&sqp=CLmu-cwG&rs=AOn4CLAvZPhOxdqXktUCQB82AomL0xdS-Q', 'wid ...

# %%
from youtube_transcript_api import TranscriptList, YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
MAX_SNIPPETS = 50

def api_call(video_id: str, languages: list[str]) -> TranscriptList:
    """Fetches the transcript for a given YouTube video ID in the specified languages.
    Args:
        video_id (str): The unique identifier for the YouTube video
        languages (list[str]): A list of language codes (e.g., ["de", "es"]) it will first try to fetch the german transcript ('de') and then fetch the english transcript ('en') if it fails to do so.
    Returns:
        list[dict]: A list of transcript snippets, where each snippet is a dictionary containing the text of the transcript and its corresponding start time and duration. For example:
        [
            {"text": "Hello, welcome to this video.", "start": 0.0, "duration": 5.0},
        ]    
    """
    try: 
        transcript_list = ytt_api.list(video_id)
        transcript = transcript_list.find_transcript(languages)
        return transcript
    except:
        raise Exception(f"Could not fetch transcript for video ID {video_id} in languages {languages}.")

# %%
from youtube_transcript_api import Transcript, YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
MAX_SNIPPETS = 50

def api_call(video_id: str, languages: list[str]) -> Transcript:
    """Fetches the transcript for a given YouTube video ID in the specified languages.
    Args:
        video_id (str): The unique identifier for the YouTube video
        languages (list[str]): A list of language codes (e.g., ["de", "es"]) it will first try to fetch the german transcript ('de') and then fetch the english transcript ('en') if it fails to do so.
    Returns:
        tuple[str, str]: A tuple containing the language code and a single concatenated string containing the text of the transcript. For example:
        ("de", "Hello, welcome to this video. In this video, we will discuss...")
    """
    try: 
        transcript_list = ytt_api.list(video_id)
        transcript = transcript_list.find_transcript(languages)
        return transcript
    
    except Exception as e:
        raise Exception(f"Could not fetch transcript... Error: {e}")

def get_transcript(video_id: str, languages: list[str]) -> tuple[str, str]:
    """Fetches the transcript for a given YouTube video ID in the specified languages and returns it as a single concatenated string.
    Args:
        video_id (str): The unique identifier for the YouTube video
        languages (list[str]): A list of language codes (e.g., ["de", "es"]) it will first try to fetch the german transcript ('de') and then fetch the english transcript ('en') if it fails to do so.
    Returns:
        tuple[str, str]: A tuple containing the language code and a single concatenated string containing the text of the transcript. For example:
        ("de", "Hello, welcome to this video. In this video, we will discuss...")
    """
    transcript = api_call(video_id, languages)
    str_snippets = transcript.fetch()[:MAX_SNIPPETS]
    concat_str = " ".join([snippet.text for snippet in str_snippets])

    language_code = transcript.language_code
    return language_code, concat_str

# %%
get_transcript("ZSX3xmu11a8", ["fr", "en"])
# Out:
# ('fr',
#  "bon on est déjà en 2024 j'ai créé cinq vidéos que j'ai adoré faire et maintenant je me trouve un peu dans l'embarras parce que ça fait maintenant plusieurs mois que je repousse quelque chose un sujet bien particulier qui m'a bercé pendant toute mon adolescence je savais pas trop comment l'aborder parce qu'il est plus personnel et émotionnel que les autres si dans mes cinq précédentes vidéos j'ai fait de la review narrative avec un peu de gameplay là ce sera purement du storytelling sur un sujet qui m'est très cher dans cette vidéo je vais pas parler d'un jeu en particulier mais plutôt d'une expérience évidemment c'est toujours propre à chacun surtout dans la manière de nous marquer pour certains ça a été un sport en particulier à une époque pour d'autres ça a pu être certaines vacances passées sous les tropiques et pour moi ça a été à [Musique] [Musique] l'au [Musique] bon vous pouvez rire c'est effectivement le discours de l'énorme geek qui n'a jamais particulièrement apprécié les bains de soleil pour ceux qui s'attendent à une rétrospective complète de la licence de 2001 à aujourd'hui ça ne va pas être exactement le cas je vais vous expliquer un tas d'éléments pour vous faire comprendre son âge d'or tout en passant par les raisons de sa chute qui est toujours actuelle avec ho infinite ou ho 6 le dernier en date aujourd'hui Ho est une licence qui a complètement disparu du paysage vidéoludique et même si infinite que je viens de citer fait une légère remontée ces derniers mois il a mis le dernier clou sur le cercueil de la confiance qu'avaient les fan en halo faut se remettre en tête qu'à l'époque cette licence faisait de bien meilleures ventes que Call of Duty bien évidemment aujourd'hui c'est plus le cas avec tous")
