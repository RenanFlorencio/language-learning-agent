# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv(override=True)
# Out:
# True

# %%
os.environ["RAPIDAPI_KEY"]
# Out:
# '8685c17582mshb74f0d5f6e7ff1bp13d00ajsn1f8233ae3585'

# %%
import requests

url = "https://youtube138.p.rapidapi.com/search/"

headers = {
	"x-rapidapi-key": os.environ.get("RAPIDAPI_KEY"),
	"x-rapidapi-host": "youtube138.p.rapidapi.com",
    "q": "recettes francaises",
    "hl": "",
    "gl": ""
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'contents': [{'channel': {'avatar': [{'height': 88, 'url': 'https://yt3.ggpht.com/d_QVqeZQ7B0aFJ_pSAbPsA5VDKae8LCQWbRRbA5P5wRzCyR7koLSXWy4VEthON9MN7VABqSO1A=s88-c-k-c0x00ffffff-no-rj-mo', 'width': 88}, {'height': 176, 'url': 'https://yt3.ggpht.com/d_QVqeZQ7B0aFJ_pSAbPsA5VDKae8LCQWbRRbA5P5wRzCyR7koLSXWy4VEthON9MN7VABqSO1A=s176-c-k-c0x00ffffff-no-rj-mo', 'width': 176}], 'badges': [{'text': 'Verified', 'type': 'VERIFIED_CHANNEL'}], 'canonicalBaseUrl': '/@InaLesRecettesVintage', 'channelId': 'UC7gnE1bBnH7FCJE_MFgVrzg', 'descriptionSnippet': 'Abonnez-vous http://bit.ly/InaLesRecettesVintages Découvrez les meilleures recettes des émissions culinaires de la télévision\xa0...', 'stats': {'subscribers': 127000, 'subscribersText': '127K subscribers'}, 'title': 'Ina Les Recettes Vintage', 'username': '@InaLesRecettesVintage'}, 'type': 'channel'}, {'type': 'video', 'video': {'author': {'avatar': [{'height': 68, 'url': 'https://yt3.ggpht.com/ErjhKdz74ibAUiJPy0dkhY05m9Wu0kXrRccemeO6-zIPg2FuTeud_8PEX6gIQONjPO9ED_0EpA=s68-c-k-c0x00ffffff-no-rj', 'width': 68}], 'badges': [{'text': 'Verified', 'type': 'VERIFIED_CHANNEL'}], 'canonicalBaseUrl': '/@francaisavecnelly', 'channelId': 'UClEGQZlQURxTiMdwBPqiKDQ', 'title': 'Français avec Nelly'}, 'badges': ['CC'], 'descriptionSnippet': "Pourquoi mange-t-on des crêpes à la Chandeleur ? Dans cette vidéo, je t'explique l'origine de cette tradition française et ce\xa0...", 'isLiveNow': False, 'lengthSeconds': 542, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/PWKVwUXPa44/mqdefault_6s.webp?du=3000&sqp=CIqJw80G&rs=AOn4CLDoMVqSmxqtN0_6QVh673ACBPVyHw', 'width': 320}], 'publishedTimeText': '1 year ago', 'stats': {'views': 78604}, 'thumbnails': [{'height': 202, 'url': 'https://i.ytimg.com/vi/PWKVwUXPa44/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCBH8rrVGfUIzQUbF7ezWUotmoBnw', 'width': 360}, {'height': 404, 'url': 'https://i.ytimg.com/vi/PWKVwUXPa44/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCHpdss9gHYnyE1sd_wk7te9TG-aw', 'width': 720}], 'title': 'Pourquoi les Français Mangent des Crêpes le 2 Février ? + recette de crêpes françaises', 'videoId': 'PWKVwUXPa44'}}, {'type': 'video', 'video': {'author': {'avatar': [{'height': 68, 'url': 'https://yt3.ggpht.com/xvgn3FOSzECDJTyh_cK73GPxsfADQkXGxiRpd97gmp5ARac7o6qGTAshynQHLfFxyI05sTOC_A=s68-c-k-c0x00ffffff-no-rj', 'width': 68}], 'badges': [{'text': 'Verified', 'type': 'VERIFIED_CHANNEL'}], 'canonicalBaseUrl': '/@100docs', 'channelId': 'UC7DHcyYJpGiSO0NIE7w_Eug', 'title': '100% DOCS - Reportages & Documentaires'}, 'badges': [], 'descriptionSnippet': "Documentaire consacré à la tradition culinaire française. Alternance d'images d'archives ayant trait à l'histoire de la cuisine\xa0...", 'isLiveNow': False, 'lengthSeconds': 6391, 'movingThumbnails': [{'height': 180, 'url': 'https://i.ytimg.com/an_webp/Xu-FLmk7t5Y/mqdefault_6s.webp?du=3000&sqp=CJaUw80G&rs=AOn4CLDtEz144NCSaXLutrxHbQVyiPrZYg', 'width': 320}], 'publishedTimeText': '4 years ago', 'stats': {'views': 834813}, 'thumbnails': [{'height': 202, 'url': 'https://i.ytimg.com/vi/Xu-FLmk7t5Y/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDrhQzEVm_6EWqs91AmaU7mG1rl2Q', 'width': 360}, {'height': 404, 'url': 'https://i.ytimg.com/vi/Xu-FLmk7t5Y/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLByn1nA7IUIF5fPEcL2T6OjRAfAaA', 'width': 720}], 'title': "LA CUISINE FRANCAISE : C'EST SACRÉ !", 'videoId': 'Xu-FLmk7t5Y'}}, {'type': 'video', 'video': {'author': {'avatar': [{'height': 68, 'url': 'https://yt3.ggpht.com/ytc/AIdro_m68GNx4VZ0xsiEnmNYp0ZCUtNm1P6WooFMzE9d1NNCUw=s68-c-k-c0x00ffffff-no-rj', 'width': 68}], 'badges': [], 'canonicalBaseUrl': '/@TradiCuisine', 'channelId': 'UC6XhUxvJadB4O4CJxcI8JyQ', 'title': 'TradiCuisine by Ocena Milly (Tradicuisine)'}, 'badges': [], 'descriptionSnippet': 'La liste des ingrédients est donnée ci-dessous. Pour la recette détaillée, rendez-vous sur mon site web\xa0...', ' ...

# %%
from youtube_transcript_api import TranscriptList, YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
MAX_SNIPPETS = 50

def api_call(video_id: str, languages: list[str]) -> TranscriptList:
    """Fetches the transcript for a given YouTube video ID in the specified languages.
    Args:
        video_id (str): The unique identifier for the YouTube video
        languages (list[str]): A list of language codes (e.g., ["de", "es"]) it will first try to fetch the german transcript ('de') and then fetch the english transcript ('en') if it fails to do so.
    Returns:
        list[dict]: A list of transcript snippets, where each snippet is a dictionary containing the text of the transcript and its corresponding start time and duration. For example:
        [
            {"text": "Hello, welcome to this video.", "start": 0.0, "duration": 5.0},
        ]    
    """
    try: 
        transcript_list = ytt_api.list(video_id)
        transcript = transcript_list.find_transcript(languages)
        return transcript
    except:
        raise Exception(f"Could not fetch transcript for video ID {video_id} in languages {languages}.")

# %%
from youtube_transcript_api import Transcript, YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
MAX_SNIPPETS = 50

def api_call(video_id: str, languages: list[str]) -> Transcript:
    """Fetches the transcript for a given YouTube video ID in the specified languages.
    Args:
        video_id (str): The unique identifier for the YouTube video
        languages (list[str]): A list of language codes (e.g., ["de", "es"]) it will first try to fetch the german transcript ('de') and then fetch the english transcript ('en') if it fails to do so.
    Returns:
        tuple[str, str]: A tuple containing the language code and a single concatenated string containing the text of the transcript. For example:
        ("de", "Hello, welcome to this video. In this video, we will discuss...")
    """
    try: 
        transcript_list = ytt_api.list(video_id)
        transcript = transcript_list.find_transcript(languages)
        return transcript
    
    except Exception as e:
        raise Exception(f"Could not fetch transcript... Error: {e}")

def get_transcript(video_id: str, languages: list[str]) -> tuple[str, str]:
    """Fetches the transcript for a given YouTube video ID in the specified languages and returns it as a single concatenated string.
    Args:
        video_id (str): The unique identifier for the YouTube video
        languages (list[str]): A list of language codes (e.g., ["de", "es"]) it will first try to fetch the german transcript ('de') and then fetch the english transcript ('en') if it fails to do so.
    Returns:
        tuple[str, str]: A tuple containing the language code and a single concatenated string containing the text of the transcript. For example:
        ("de", "Hello, welcome to this video. In this video, we will discuss...")
    """
    transcript = api_call(video_id, languages)
    str_snippets = transcript.fetch()[:MAX_SNIPPETS]
    concat_str = " ".join([snippet.text for snippet in str_snippets])

    language_code = transcript.language_code
    return language_code, concat_str

# %%
get_transcript("ZSX3xmu11a8", ["fr", "en"])
# Out:
# ('fr',
#  "bon on est déjà en 2024 j'ai créé cinq vidéos que j'ai adoré faire et maintenant je me trouve un peu dans l'embarras parce que ça fait maintenant plusieurs mois que je repousse quelque chose un sujet bien particulier qui m'a bercé pendant toute mon adolescence je savais pas trop comment l'aborder parce qu'il est plus personnel et émotionnel que les autres si dans mes cinq précédentes vidéos j'ai fait de la review narrative avec un peu de gameplay là ce sera purement du storytelling sur un sujet qui m'est très cher dans cette vidéo je vais pas parler d'un jeu en particulier mais plutôt d'une expérience évidemment c'est toujours propre à chacun surtout dans la manière de nous marquer pour certains ça a été un sport en particulier à une époque pour d'autres ça a pu être certaines vacances passées sous les tropiques et pour moi ça a été à [Musique] [Musique] l'au [Musique] bon vous pouvez rire c'est effectivement le discours de l'énorme geek qui n'a jamais particulièrement apprécié les bains de soleil pour ceux qui s'attendent à une rétrospective complète de la licence de 2001 à aujourd'hui ça ne va pas être exactement le cas je vais vous expliquer un tas d'éléments pour vous faire comprendre son âge d'or tout en passant par les raisons de sa chute qui est toujours actuelle avec ho infinite ou ho 6 le dernier en date aujourd'hui Ho est une licence qui a complètement disparu du paysage vidéoludique et même si infinite que je viens de citer fait une légère remontée ces derniers mois il a mis le dernier clou sur le cercueil de la confiance qu'avaient les fan en halo faut se remettre en tête qu'à l'époque cette licence faisait de bien meilleures ventes que Call of Duty bien évidemment aujourd'hui c'est plus le cas avec tous")
